# %%
import os
# %pwd
os.chdir('../')

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class TrainingConfig:
    root_dir: Path
    trained_model_path: Path
    updated_base_model_path: Path
    training_data: Path
    params_epochs: int
    params_batch_size: int
    params_is_augmentation: bool
    params_image_size: list

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(self, config_filepath = CONFIG_FILE_PATH, params_filepath = PARAMS_FILE_PATH):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        create_directories([self.config.artifacts_root])

    def get_training_config(self) -> TrainingConfig:
        training = self.config.training
        prepare_base_model = self.config.prepare_base_model
        params = self.params
        training_data = os.path.join(self.config.data_ingestion.unzip_dir, "kidney-ct-scan-image")
        create_directories([
            Path(training.root_dir)
        ])

        training_config = TrainingConfig(
            root_dir=Path(training.root_dir),
            trained_model_path=Path(training.trained_model_path),
            updated_base_model_path=Path(prepare_base_model.updated_base_model_path),
            training_data=Path(training_data),
            params_epochs=params.EPOCHS,
            params_batch_size=params.BATCH_SIZE,
            params_is_augmentation=params.AUGMENTATION,
            params_image_size=params.IMAGE_SIZE
        )

        return training_config

# %%
import os
import urllib.request as request
from zipfile import ZipFile
import tensorflow as tf
import time

# %%
class Training:
    def __init__(self, config: TrainingConfig):
        self.config = config

    def get_base_model(self):
        self.model = tf.keras.models.load_model(self.config.updated_base_model_path )

    def train_valid_generator(self):
        datagenerator_kwargs = dict(
            rescale = 1./255,
            validation_split=0.20
        )
        dataflow_kwargs = dict(
            target_size=self.config.params_image_size[:-1],
            batch_size=self.config.params_batch_size,
            interpolation="bilinear"
        )
        valid_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
            **datagenerator_kwargs
        )
        self.valid_generator = valid_datagenerator.flow_from_directory(
            directory=self.config.training_data,
            subset="validation",
            shuffle=False,
            **dataflow_kwargs
        )
        if self.config.params_is_augmentation:
            train_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
                rotation_range=40,
                horizontal_flip=True,
                width_shift_range=0.2,
                height_shift_range=0.2,
                shear_range=0.2,
                zoom_range=0.2,
                **datagenerator_kwargs
            )
        else:
            train_datagenerator = valid_datagenerator

        self.train_generator = train_datagenerator.flow_from_directory(
            directory=self.config.training_data,
            subset="training",
            shuffle=True,
            **dataflow_kwargs
        )


    @staticmethod
    def save_model(path: Path, model: tf.keras.Model):
        model.save(path)
    
    def train(self):
        self.steps_per_epoch = self.train_generator.samples // self.train_generator.batch_size
        self.validation_steps = self.valid_generator.samples // self.valid_generator.batch_size

        self.model.fit(
            self.train_generator,
            epochs=self.config.params_epochs,
            steps_per_epoch=self.steps_per_epoch,
            validation_steps=self.validation_steps,
            validation_data=self.valid_generator
        )

        self.save_model(
            path=self.config.trained_model_path,
            model=self.model
        )

# %%
try:
    config = ConfigurationManager()
    training_config = config.get_training_config()
    training = Training(config=training_config)
    training.get_base_model()
    training.train_valid_generator()
    training.train()
    
except Exception as e:
    raise e
# Out:
# [2023-10-11 20:48:29,394: Type-> INFO: File-> common: Message-> yaml file: config\config.yaml loaded successfully]
# [2023-10-11 20:48:29,398: Type-> INFO: File-> common: Message-> yaml file: params.yaml loaded successfully]
# [2023-10-11 20:48:29,402: Type-> INFO: File-> common: Message-> created directory at: artifacts]
# [2023-10-11 20:48:29,402: Type-> INFO: File-> common: Message-> created directory at: artifacts\training]
# Found 93 images belonging to 2 classes.
# Found 372 images belonging to 2 classes.
# Epoch 1/25
# 23/23 [==============================] - 90s 4s/step - loss: 10.7135 - accuracy: 0.5927 - val_loss: 29.6462 - val_accuracy: 0.4000
# Epoch 2/25
# 23/23 [==============================] - 96s 4s/step - loss: 4.4687 - accuracy: 0.7051 - val_loss: 10.2303 - val_accuracy: 0.4375
# Epoch 3/25
# 23/23 [==============================] - 100s 4s/step - loss: 4.9599 - accuracy: 0.6902 - val_loss: 26.3148 - val_accuracy: 0.4000
# Epoch 4/25
# 23/23 [==============================] - 101s 4s/step - loss: 6.3304 - accuracy: 0.7331 - val_loss: 9.3054 - val_accuracy: 0.4750
# Epoch 5/25
# 23/23 [==============================] - 101s 4s/step - loss: 2.0422 - accuracy: 0.7978 - val_loss: 11.5586 - val_accuracy: 0.6000
# Epoch 6/25
# 23/23 [==============================] - 102s 4s/step - loss: 4.2180 - accuracy: 0.7697 - val_loss: 0.6511 - val_accuracy: 0.8625
# Epoch 7/25
# 23/23 [==============================] - 105s 5s/step - loss: 1.1245 - accuracy: 0.8832 - val_loss: 0.2355 - val_accuracy: 0.9625
# Epoch 8/25
# 23/23 [==============================] - 102s 4s/step - loss: 0.9726 - accuracy: 0.8652 - val_loss: 0.0432 - val_accuracy: 0.9625
# Epoch 9/25
# 23/23 [==============================] - 109s 5s/step - loss: 1.3915 - accuracy: 0.8624 - val_loss: 0.0937 - val_accuracy: 0.9375
# Epoch 10/25
# 23/23 [==============================] - 2260s 103s/step - loss: 2.2854 - accuracy: 0.8371 - val_loss: 0.1049 - val_accuracy: 0.9375
# Epoch 11/25
# 23/23 [==============================] - 81s 4s/step - loss: 0.4535 - accuracy: 0.9213 - val_loss: 1.4254 - val_accuracy: 0.5875
# Epoch 12/25
# 23/23 [==============================] - 81s 4s/step - loss: 3.0727 - accuracy: 0.7725 - val_loss: 0.4526 - val_accuracy: 0.9125
# Epoch 13/25
# 23/23 [==============================] - 86s 4s/step - loss: 0.8934 - accuracy: 0.8933 - val_loss: 0.0541 - val_accuracy: 0.9625
# Epoch 14/25
# 23/23 [==============================] - 91s 4s/step - loss: 0.2743 - accuracy: 0.9410 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 15/25
# 23/23 [==============================] - 97s 4s/step - loss: 0.2655 - accuracy: 0.9607 - val_loss: 0.0380 - val_accuracy: 0.9625
# Epoch 16/25
# 23/23 [==============================] - 132s 6s/step - loss: 1.5484 - accuracy: 0.8876 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 17/25
# 23/23 [==============================] - 112s 5s/step - loss: 0.2376 - accuracy: 0.9522 - val_loss: 9.7962e-04 - val_accuracy: 1.0000
# Epoch 18/25
# 23/23 [==============================] - 113s 5s/step - loss: 0.0767 - accuracy: 0.9860 - val_loss: 4.9592e-05 - val_accuracy: 1.0000
# Epoch 19/25
# 23/23 [==============================] - 121s 5s/step - loss: 0.0826 - accuracy: 0.9860 - val_loss: 1.7536e-05 - val_accuracy: 1.0000
# Epoch 20/25
# 23/23 [==============================] - 118s 5s/step - loss: 0.0447 - accuracy: 0.9775 - val_loss: 1.2024e-05 - val_accuracy: 1.0000
# Epoch 21/25
# 23/23 [==============================] - 139s 6s/step - loss: 0.0860 - accuracy: 0.9691 - val_loss: 1.4474e-05 - val_accuracy: 1.0000
# Epoch 22/25
# 23/23 [==============================] - 122s 5s/step - loss: 0.1235 - accuracy: 0.9719 - val_loss: 1.0201e-05 - val_accuracy: 1.0000
# Epoch 23/25
# 23/23 [==============================] - 103s 4s/step - loss: 0.0908 - accuracy: 0.9719 - val_loss: 0.1033 - val_accuracy: 0.9375
# Epoch 24/25
# 23/23 [==============================] - 101s 4s/step - loss: 0.0963 - accuracy: 0.9803 - val_loss: 0.3206 - val_accuracy: 0.8375
# Epoch 25/25
# 23/23 [==============================] - 103s 4s/step - loss: 0.0953 - accuracy: 0.9728 - val_loss: 3.8365e-04 - val_accuracy: 1.0000
# c:\Users\abhis\OneDrive\Desktop\kidney_disease_classification\env\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
